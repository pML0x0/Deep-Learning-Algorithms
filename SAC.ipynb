# %%
#Path related stuff
import os
import copy

#Math stuff
import numpy as np
import random

#Environment stuff
import gym
#import mujoco_py


#Pytorch Stuff 
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Normal
import torch.nn.functional as F
from torch.optim import Adam
from torch.optim import NAdam

# %%
class ReplayBuffer:
  def __init__(self, buffer_size, batch_size, seed = 4):
    self.buffer = []
    self.max_size = buffer_size
    self.batch_size = batch_size
    self.random_generator = np.random.RandomState(seed)

  def append(self, state, action, noise_action, reward, terminal, next_state):
    if(len(self.buffer) == self.max_size):
      del self.buffer[0]

    self.buffer.append([state, action, noise_action, reward, terminal, next_state])

  def sample(self):
    batch = random.sample(self.buffer, self.batch_size)

    state, action, noise_action, reward, terminal, next_state = map(np.stack, zip(*batch))
    
    return state, action, noise_action, reward, terminal, next_state

  def get_buffer_size(self):
    return len(self.buffer)

# %%
LOG_SIG_MAX = 2
LOG_SIG_MIN = -20
epsilon = 1e-6

#Initialize Policy weights
def weights_init_(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight, gain=1)
        torch.nn.init.constant_(m.bias, 0)

class QNetwork(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_dim):
        super(QNetwork, self).__init__()
        

        #n_action = *num_actions
        # Q1 architecture
        self.linear1 = nn.Linear(*np.add(num_inputs, num_actions), hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, hidden_dim)
        self.linear3 = nn.Linear(hidden_dim, hidden_dim)
        self.linear4 = nn.Linear(hidden_dim, 1)

        # Q2 architecture
        self.linear5 = nn.Linear(*np.add(num_inputs, num_actions), hidden_dim)
        self.linear6 = nn.Linear(hidden_dim, hidden_dim)
        self.linear7 = nn.Linear(hidden_dim, hidden_dim)
        self.linear8 = nn.Linear(hidden_dim, 1)

        self.apply(weights_init_)

    def forward(self, state, action):
        xu = torch.cat([state, action], 1)
        
        x1 = F.relu(self.linear1(xu))
        x1 = F.relu(self.linear2(x1))
        x1 = F.relu(self.linear3(x1))
        
        x1 = self.linear4(x1)

        x2 = F.relu(self.linear5(xu))
        x2 = F.relu(self.linear6(x2))
        x2 = F.relu(self.linear7(x2))
        x2 = self.linear8(x2)

        return x1, x2


class GaussianPolicy(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_dim, action_range=None):
        super(GaussianPolicy, self).__init__()
        
        self.linear1 = nn.Linear(*num_inputs, hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, hidden_dim)
        self.linear3 = nn.Linear(hidden_dim, hidden_dim)

        self.mean_linear = nn.Linear(hidden_dim, *num_actions)
        self.log_std_linear = nn.Linear(hidden_dim, *num_actions)

        self.apply(weights_init_)

        # action rescaling
        if action_range is None:
            self.action_scale = torch.tensor(1.)
            self.action_bias = torch.tensor(0.)
        else:
            self.action_scale = torch.FloatTensor([
                (np.max(action_range) - np.min(action_range)) / 2.
                ])
            self.action_bias = torch.FloatTensor([
                (np.max(action_range) - np.max(action_range)) / 2.
                ])

    def forward(self, state):
        x = F.relu(self.linear1(state))
        x = F.relu(self.linear2(x))
        x = F.relu(self.linear3(x))

        mean = self.mean_linear(x)
        log_std = self.log_std_linear(x)
        log_std = torch.clamp(log_std, min=LOG_SIG_MIN, max=LOG_SIG_MAX)
        return mean, log_std

    def sample(self, state):
        
        mean, log_std = self.forward(state)
        std = log_std.exp()
        normal = Normal(mean, std)
        x_t = normal.rsample()  # for reparameterization trick (mean + std * N(0,1))
        y_t = torch.tanh(x_t)
        action = y_t * self.action_scale + self.action_bias
        log_prob = normal.log_prob(x_t)
        # Enforcing Action Bound
        log_prob -= torch.log(self.action_scale * (1 - y_t.pow(2)) + epsilon)
        log_prob = log_prob.sum(1, keepdim=True)
        
        mean = torch.tanh(mean) * self.action_scale + self.action_bias
        return action, log_prob, mean, std

    def to(self, device):
        self.action_scale = self.action_scale.to(device)
        self.action_bias = self.action_bias.to(device)
        return super(GaussianPolicy, self).to(device)

# %%
class SAC_Agent(object):
    def __init__(self, observation_space, action_space, gamma, c_lr, a_lr,  tau, alpha, hidden_network_size, 
                 action_range, batch_size):
      

        self.REPLAY_BATCH_SIZE = batch_size
        self.replay_buffer = ReplayBuffer(1000000, self.REPLAY_BATCH_SIZE)

        self.gamma = gamma
        self.clr = c_lr
        self.alr = a_lr
        self.tau = tau
        self.alpha = alpha

        self.device = "cuda:0" if torch.cuda.is_available() else "cpu"

      

        self.critic = QNetwork(observation_space, action_space, hidden_network_size).to(device=self.device)
        self.critic_optim = Adam(self.critic.parameters(), lr=self.clr)

        self.critic_target = QNetwork(observation_space, action_space, hidden_network_size).to(self.device)
        

        #perfoming a soft copy of the parameters
        for target_param, param in zip( self.critic_target.parameters(), self.critic.parameters()):
            target_param.data.copy_( param.data * self.tau + (1-self.tau) * target_param.data)

        self.policy = GaussianPolicy(observation_space, action_space, hidden_network_size, action_range).to(self.device)
        self.policy_optim = Adam(self.policy.parameters(), lr=self.alr)


        self.target_entropy = -torch.prod(torch.Tensor(*action_space).to(self.device)).item()
        self.log_alpha = torch.zeros(1, requires_grad=True, device=self.device)
        self.alpha_optim = NAdam([self.log_alpha], lr=0.00005)


    def select_action(self, state, evaluate=False):
        state = torch.FloatTensor([state]).to(self.device)
        if evaluate is False:
            action, _, _, _ = self.policy.sample(state)

        return action.cpu().detach().numpy()[0]

    
    def update_parameters(self):
        # Sample a batch from memory
        if self.replay_buffer.get_buffer_size() < self.REPLAY_BATCH_SIZE:
            return

        state_batch, action_batch, noise_action_batch, reward_batch, mask_batch, next_state_batch = self.replay_buffer.sample()

        state_batch = torch.FloatTensor(state_batch).to(self.device)
        next_state_batch = torch.FloatTensor(next_state_batch).to(self.device)
        action_batch = torch.FloatTensor(action_batch).to(self.device)
        reward_batch = torch.FloatTensor(reward_batch).to(self.device).unsqueeze(1)
        mask_batch = torch.FloatTensor(mask_batch).to(self.device).unsqueeze(1)
        
        noise_action_batch = torch.FloatTensor(noise_action_batch).to(self.device)

        intrinsic_reward = torch.norm(action_batch - noise_action_batch, p=2, dim=1, keepdim=True)
        

        with torch.no_grad():

            next_state_action, next_state_log_pi, _, _ = self.policy.sample(next_state_batch)
            
            qf1_next_target, qf2_next_target = self.critic_target(next_state_batch, next_state_action)
            min_qf_next_target = torch.min(qf1_next_target, qf2_next_target) - self.alpha * next_state_log_pi
            next_q_value = (reward_batch - intrinsic_reward) + (1-mask_batch) * self.gamma * (min_qf_next_target)

        qf1, qf2 = self.critic(state_batch, action_batch) # Two Q-functions to mitigate positive bias in the policy improvement step

        qf1_loss = F.mse_loss(qf1, next_q_value)
        qf2_loss = F.mse_loss(qf2, next_q_value) 
       
        qf_loss = (qf1_loss + qf2_loss).mean()
        
        self.critic_optim.zero_grad()
        qf_loss.backward()
        self.critic_optim.step()

        for target_param, param in zip( self.critic_target.parameters(), self.critic.parameters()):
            target_param.data.copy_( param.data * self.tau + (1-self.tau) * target_param.data)
        

        pi, log_pi, _, _ = self.policy.sample(state_batch)
        

        qf1_pi, qf2_pi = self.critic(state_batch, pi)
        min_qf_pi = torch.min(qf1_pi, qf2_pi)
        policy_loss = ((self.alpha * log_pi) - min_qf_pi).mean()

        self.policy_optim.zero_grad()
        policy_loss.backward()
        self.policy_optim.step()


        # alpha_loss = -(self.log_alpha * (log_pi + self.target_entropy).detach()).mean()
        # self.alpha_optim.zero_grad()
        # alpha_loss.backward()
        # self.alpha_optim.step()

        return qf1_loss.item(), qf2_loss.item(), policy_loss.item()

# %%
import gym
import numpy as np
#from utils import plotLearning

# %%
env = gym.make('LunarLanderContinuous-v2')
env2 = gym.make('LunarLanderContinuous-v2')
agent = SAC_Agent(observation_space = [8], action_space=[2], gamma=0.99, c_lr = 0.00025, a_lr = 0.000025, tau = 0.001, alpha = 1.9, hidden_network_size = 256, action_range = [-1,1], batch_size=64)


np.random.seed(0)

score_history = []

for i in range(1500):
    done = False
    score = 0
    obs = env.reset()[0]
    
    for _ in range(600):
        noisy_state_1 = copy.deepcopy(obs)
        noise = np.random.normal(0,0.05, size=6)
        noise = np.concatenate(([0.0,0.0],noise))
        noisy_obs = np.add(obs, noise)
        
        act_noise = agent.select_action(noisy_obs)
        
        #--------------------------------------------------------
        #--------------------------------------------------------

        act = agent.select_action(obs)
        new_state, reward, done, info, _ = env.step(act)
   
        agent.replay_buffer.append(obs, act, act_noise, reward, int(done), new_state)
        agent.update_parameters()
        
        score += reward

        if done:
            break
        
        obs = new_state

    score_history.append(score)
    print('episode', i, 'score %.2f' % score, '100 game average %.2f' % np.mean(score_history[-100:]))
    

    # if i % 25 == 0:
    #     agent.save_models()

# filename = 'lunar-lander.png'
# plotLearning(score_history, filename, window=100)
# Out:
# /home/padjei/miniconda3/envs/rlenv2/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# episode 0 score -89.48 100 game average -89.48
# episode 1 score -161.01 100 game average -125.24
# episode 2 score -76.35 100 game average -108.94
# episode 3 score -312.21 100 game average -159.76
# episode 4 score -529.76 100 game average -233.76
# episode 5 score -94.80 100 game average -210.60
# episode 6 score -214.61 100 game average -211.17
# episode 7 score -115.99 100 game average -199.28
# episode 8 score -75.18 100 game average -185.49
# episode 9 score -226.20 100 game average -189.56
# episode 10 score 22.16 100 game average -170.31
# episode 11 score -546.15 100 game average -201.63
# episode 12 score -91.80 100 game average -193.18
# episode 13 score -161.43 100 game average -190.91
# episode 14 score -118.70 100 game average -186.10
# episode 15 score -237.56 100 game average -189.32
# episode 16 score -278.75 100 game average -194.58
# episode 17 score -71.93 100 game average -187.76
# episode 18 score -91.23 100 game average -182.68
# episode 19 score -251.60 100 game average -186.13
# episode 20 score -5.55 100 game average -177.53
# episode 21 score -81.53 100 game average -173.17
# episode 22 score -201.54 100 game average -174.40
# episode 23 score -284.81 100 game average -179.00
# episode 24 score -223.23 100 game average -180.77
# episode 25 score -40.57 100 game average -175.38
# episode 26 score -104.75 100 game average -172.76
# episode 27 score -31.05 100 game average -167.70
# episode 28 score -173.34 100 game average -167.89
# episode 29 score 11.45 100 game average -161.92
# episode 30 score -474.02 100 game average -171.98
# episode 31 score -223.52 100 game average -173.59
# episode 32 score -11.38 100 game average -168.68
# episode 33 score 8.24 100 game average -163.48
# episode 34 score -6.07 100 game average -158.98
# episode 35 score -217.96 100 game average -160.62
# episode 36 score -91.75 100 game average -158.76
# episode 37 score -66.05 100 game average -156.32
# episode 38 score -134.21 100 game average -155.75
# episode 39 score -97.90 100 game average -154.30
# episode 40 score -168.01 100 game average -154.64
# episode 41 score -124.42 100 game average -153.92
# episode 42 score -56.00 100 game average -151.64
# episode 43 score -49.64 100 game average -149.32
# episode 44 score -79.57 100 game average -147.77
# episode 45 score -235.60 100 game average -149.68
# episode 46 score -217.74 100 game average -151.13
# episode 47 score -74.85 100 game average -149.54
# episode 48 score -164.30 100 game average -149.84
# episode 49 score -36.62 100 game average -147.58
# episode 50 score -121.61 100 game average -147.07
# episode 51 score -18.24 100 game average -144.59
# episode 52 score -104.10 100 game average -143.83
# episode 53 score -154.09 100 game average -144.02
# episode 54 score -51.58 100 game average -142.34
# episode 55 score -62.89 100 game average -140.92
# episode 56 score -166.47 100 game average -141.37
# episode 57 score -12.31 100 game average -139.14
# episode 58 score -208.69 100 game average -140.32
# episode 59 score 41.51 100 game average -137.29
# episode 60 score 73.59 100 game average -133.83
# episode 61 score -12.47 100 game average -131.87
# episode 62 score -26.00 100 game average -130.19
# episode 63 score -195.73 100 game average -131.22
# episode 64 score 27.90 100 game average -128.77
# episode 65 score -232.18 100 game average -130.34
# episode 66 score -1.16 100 game average -128.41
# episode 67 score 7.45 100 game average -126.41
# episode 68 score -4.14 100 game average -124.64
# episode 69 score -36.50 100 game average -123.38
# episode 70 score -25.75 100 game average -122.00
# episode 71 score -80.77 100 game average -121.43
# episode 72 score -41.38 100 game average -120.34
# episode 73 score 3.09 100 game average -118.67
# episode 74 score -18.93 100 game average -117.34
# episode 75 score -26.85 100 game average -116.15
# episode 76 score -22.70 100 game average -114.93
# episode 77 score 137.36 100 game average -111.70
# episode 78 score -20.67 100 game average -110.55
# episode 79 score -43.63 100 game average -109.71
# episode 80 score -66.95 100 game average -109.18
# episode 81 score 28.65 100 game average -107.50
# episode 82 score -42.54 100 game average -106.72
# episode 83 score -2.84 100 game average -105.48
# episode 84 score -44.88 100 game average -104.77
# episode 85 score 94.69 100 game average -102.45
# episode 86 score 27.42 100 game average -100.96
# episode 87 score -283.49 100 game average -103.03
# episode 88 score 19.11 100 game average -101.66
# episode 89 score 65.63 100 game average -99.80
# episode 90 score -236.85 100 game average -101.31
# episode 91 score 12.33 100 game average -100.07
# episode 92 score 8.76 100 game average -98.90
# episode 93 score -48.58 100 game average -98.37
# episode 94 score 84.50 100 game average -96.44
# episode 95 score -39.54 100 game average -95.85
# episode 96 score 85.77 100 game average -93.98
# episode 97 score 59.31 100 game average -92.41
# episode 98 score 72.40 100 game average -90.75
# episode 99 score -330.16 100 game average -93.14
# episode 100 score -5.62 100 game average -92.30
# episode 101 score 4.82 100 game average -90.64
# episode 102 score -294.66 100 game average -92.83
# episode 103 score -8.88 100 game average -89.79
# episode 104 score -61.62 100 game average -85.11
# episode 105 score 50.65 100 game average -83.66
# episode 106 score 49.02 100 game average -81.02
# episode 107 score 87.01 100 game average -78.99
# episode 108 score 65.73 100 game average -77.58
# episode 109 score -81.81 100 game average -76.14
# episode 110 score -39.42 100 game average -76.75
# episode 111 score -34.37 100 game average -71.64
# episode 112 score 22.50 100 game average -70.49
# episode 113 score 63.80 100 game average -68.24
# episode 114 score 71.35 100 game average -66.34
# episode 115 score -46.69 100 game average -64.43
# episode 116 score -2.85 100 game average -61.67
# episode 117 score -10.68 100 game average -61.06
# episode 118 score 22.08 100 game average -59.93
# episode 119 score 58.14 100 game average -56.83
# episode 120 score 63.15 100 game average -56.14
# episode 121 score -32.33 100 game average -55.65
# episode 122 score 114.75 100 game average -52.49
# episode 123 score 2.46 100 game average -49.62
# episode 124 score -14.74 100 game average -47.53
# episode 125 score 96.15 100 game average -46.16
# episode 126 score 52.59 100 game average -44.59
# episode 127 score 28.87 100 game average -43.99
# episode 128 score 75.09 100 game average -41.51
# episode 129 score 48.80 100 game average -41.13
# episode 130 score 65.42 100 game average -35.74
# episode 131 score 45.87 100 game average -33.05
# episode 132 score -112.08 100 game average -34.05
# episode 133 score -290.41 100 game average -37.04
# episode 134 score -22.70 100 game average -37.21
# episode 135 score 47.46 100 game average -34.55
# episode 136 score 41.14 100 game average -33.22
# episode 137 score 90.93 100 game average -31.65
# episode 138 score 86.36 100 game average -29.45
# episode 139 score 63.29 100 game average -27.83
# episode 140 score -63.08 100 game average -26.79
# episode 141 score -84.97 100 game average -26.39
# episode 142 score 61.44 100 game average -25.22
# episode 143 score 51.45 100 game average -24.21
# episode 144 score -103.36 100 game average -24.44
# episode 145 score 111.90 100 game average -20.97
# episode 146 score -73.49 100 game average -19.53
# episode 147 score 68.35 100 game average -18.09
# episode 148 score -105.41 100 game average -17.50
# episode 149 score 44.69 100 game average -16.69
# episode 150 score -4.49 100 game average -15.52
# episode 151 score -159.67 100 game average -16.93
# episode 152 score 50.25 100 game average -15.39
# episode 153 score 74.55 100 game average -13.10
# episode 154 score 110.10 100 game average -11.49
# episode 155 score 70.23 100 game average -10.16
# episode 156 score 64.52 100 game average -7.85
# episode 157 score 68.84 100 game average -7.04
# episode 158 score -73.84 100 game average -5.69
# episode 159 score 75.46 100 game average -5.35
# episode 160 score 116.59 100 game average -4.92
# episode 161 score 44.86 100 game average -4.34
# episode 162 score 165.80 100 game average -2.43
# episode 163 score -4.28 100 game average -0.51
# episode 164 score -1.66 100 game average -0.81
# episode 165 score -106.18 100 game average 0.45
# episode 166 score 51.68 100 game average 0.98
# episode 167 score 49.22 100 game average 1.40
# episode 168 score -14.79 100 game average 1.29
# episode 169 score 97.68 100 game average 2.63
# episode 170 score 51.40 100 game average 3.41
# episode 171 score -207.69 100 game average 2.14
# episode 172 score 76.80 100 game average 3.32
# episode 173 score 89.00 100 game average 4.18
# episode 174 score 72.04 100 game average 5.09
# episode 175 score 86.91 100 game average 6.22
# episode 176 score 119.90 100 game average 7.65
# episode 177 score 122.21 100 game average 7.50
# episode 178 score 114.45 100 game average 8.85
# episode 179 score 110.63 100 game average 10.39
# episode 180 score 84.20 100 game average 11.90
# episode 181 score 138.65 100 game average 13.00
# episode 182 score 71.99 100 game average 14.15
# episode 183 score 85.33 100 game average 15.03
# episode 184 score 103.61 100 game average 16.52
# episode 185 score 140.21 100 game average 16.97
# episode 186 score 13.02 100 game average 16.83
# episode 187 score -0.15 100 game average 19.66
# episode 188 score 83.22 100 game average 20.30
# episode 189 score 14.49 100 game average 19.79
# episode 190 score 78.73 100 game average 22.95
# episode 191 score 102.19 100 game average 23.85
# episode 192 score -60.33 100 game average 23.15
# episode 193 score 104.68 100 game average 24.69
# episode 194 score 12.85 100 game average 23.97
# episode 195 score 94.62 100 game average 25.31
# episode 196 score 105.71 100 game average 25.51
# episode 197 score 34.81 100 game average 25.27
# episode 198 score 96.74 100 game average 25.51
# episode 199 score 86.95 100 game average 29.68
# episode 200 score 121.95 100 game average 30.96
# episode 201 score 87.81 100 game average 31.79
# episode 202 score 102.18 100 game average 35.76
# episode 203 score 81.72 100 game average 36.66
# episode 204 score 89.75 100 game average 38.17
# episode 205 score 150.44 100 game average 39.17
# episode 206 score 121.26 100 game average 39.90
# episode 207 score 14.32 100 game average 39.17
# episode 208 score 94.30 100 game average 39.45
# episode 209 score 121.05 100 game average 41.48
# episode 210 score 134.90 100 game average 43.23
# episode 211 score 104.29 100 game average 44.61
# episode 212 score 124.18 100 game average 45.63
# episode 213 score 40.68 100 game average 45.40
# episode 214 score 109.76 100 game average 45.78
# episode 215 score 111.80 100 game average 47.37
# episode 216 score 102.71 100 game average 48.42
# episode 217 score 112.11 100 game average 49.65
# episode 218 score 66.38 100 game average 50.09
# episode 219 score 62.59 100 game average 50.14
# episode 220 score 81.92 100 game average 50.33
# episode 221 score 113.73 100 game average 51.79
# episode 222 score 131.04 100 game average 51.95
# episode 223 score 112.20 100 game average 53.05
# episode 224 score 59.13 100 game average 53.79
# episode 225 score 96.81 100 game average 53.79
# episode 226 score 87.61 100 game average 54.14
# episode 227 score 94.11 100 game average 54.79
# episode 228 score 110.11 100 game average 55.15
# episode 229 score 46.58 100 game average 55.12
# episode 230 score 124.39 100 game average 55.71
# episode 231 score 81.97 100 game average 56.07
# episode 232 score 55.29 100 game average 57.75
# episode 233 score 54.49 100 game average 61.20
# episode 234 score 136.19 100 game average 62.79
# episode 235 score 122.46 100 game average 63.54
# episode 236 score 111.16 100 game average 64.24
# episode 237 score 8.38 100 game average 63.41
# episode 238 score 138.27 100 game average 63.93
# episode 239 score 122.06 100 game average 64.52
# episode 240 score 100.97 100 game average 66.16
# episode 241 score 35.89 100 game average 67.37
# episode 242 score 109.48 100 game average 67.85
# episode 243 score 89.77 100 game average 68.23
# episode 244 score 117.48 100 game average 70.44
# episode 245 score 53.74 100 game average 69.86
# episode 246 score 50.25 100 game average 71.09
# episode 247 score 151.84 100 game average 71.93
# episode 248 score 119.83 100 game average 74.18
# episode 249 score 80.48 100 game average 74.54
# episode 250 score 136.94 100 game average 75.95
# episode 251 score 108.14 100 game average 78.63
# episode 252 score 67.14 100 game average 78.80
# episode 253 score 97.30 100 game average 79.03
# episode 254 score 108.69 100 game average 79.01
# episode 255 score 55.66 100 game average 78.87
# episode 256 score 104.52 100 game average 79.27
# episode 257 score 11.46 100 game average 78.69
# episode 258 score 46.07 100 game average 79.89
# episode 259 score 93.76 100 game average 80.08
# episode 260 score 125.93 100 game average 80.17
# episode 261 score 117.32 100 game average 80.89
# episode 262 score 115.03 100 game average 80.39
# episode 263 score 27.46 100 game average 80.70
# episode 264 score 135.96 100 game average 82.08
# episode 265 score 87.55 100 game average 84.02
# episode 266 score 49.64 100 game average 84.00
# episode 267 score 44.05 100 game average 83.94
# episode 268 score 114.07 100 game average 85.23
# episode 269 score -25.54 100 game average 84.00
# episode 270 score 86.72 100 game average 84.35
# episode 271 score 116.97 100 game average 87.60
# episode 272 score 24.14 100 game average 87.07
# episode 273 score 83.75 100 game average 87.02
# episode 274 score 138.40 100 game average 87.69
# episode 275 score 23.66 100 game average 87.05
# episode 276 score 92.36 100 game average 86.78
# episode 277 score 113.90 100 game average 86.69
# episode 278 score 23.62 100 game average 85.79
# episode 279 score 155.62 100 game average 86.24
# episode 280 score 119.71 100 game average 86.59
# episode 281 score 107.88 100 game average 86.28
# episode 282 score 57.14 100 game average 86.14
# episode 283 score 114.65 100 game average 86.43
# episode 284 score 115.20 100 game average 86.54
# episode 285 score 67.27 100 game average 85.81
# episode 286 score 102.69 100 game average 86.71
# episode 287 score 125.20 100 game average 87.97
# episode 288 score 42.48 100 game average 87.56
# episode 289 score 137.39 100 game average 88.79
# episode 290 score 115.28 100 game average 89.15
# episode 291 score 65.27 100 game average 88.78
# episode 292 score 123.29 100 game average 90.62
# episode 293 score 111.46 100 game average 90.69
# episode 294 score 95.95 100 game average 91.52
# episode 295 score 118.87 100 game average 91.76
# episode 296 score 53.05 100 game average 91.23
# episode 297 score 121.35 100 game average 92.10
# episode 298 score 89.68 100 game average 92.03
# episode 299 score 106.68 100 game average 92.23
# episode 300 score 137.20 100 game average 92.38
# episode 301 score 44.57 100 game average 91.95
# episode 302 score 57.38 100 game average 91.50
# episode 303 score 73.94 100 game average 91.42
# episode 304 score 90.28 100 game average 91.43
# episode 305 score 135.88 100 game average 91.28
# episode 306 score 83.54 100 game average 90.90
# episode 307 score 33.76 100 game average 91.10
# episode 308 score -20.21 100 game average 89.95
# episode 309 score 73.99 100 game average 89.48
# episode 310 score 121.60 100 game average 89.35
# episode 311 score 135.05 100 game average 89.66
# episode 312 score 31.78 100 game average 88.73
# episode 313 score 91.62 100 game average 89.24
# episode 314 score 96.29 100 game average 89.11
# episode 315 score 98.95 100 game average 88.98
# episode 316 score 60.35 100 game average 88.55
# episode 317 score -223.82 100 game average 85.20
# episode 318 score 131.07 100 game average 85.84
# episode 319 score 100.55 100 game average 86.22
# episode 320 score 124.45 100 game average 86.65
# episode 321 score 98.52 100 game average 86.49
# episode 322 score 98.80 100 game average 86.17
# episode 323 score 103.45 100 game average 86.09
# episode 324 score 131.22 100 game average 86.81
# episode 325 score 99.28 100 game average 86.83
# episode 326 score 81.41 100 game average 86.77
# episode 327 score 102.99 100 game average 86.86
# episode 328 score 113.49 100 game average 86.89
# episode 329 score 75.90 100 game average 87.18
# episode 330 score 149.77 100 game average 87.44
# episode 331 score 109.85 100 game average 87.72
# episode 332 score 144.20 100 game average 88.61
# episode 333 score 111.17 100 game average 89.17
# episode 334 score 131.91 100 game average 89.13
# episode 335 score 94.79 100 game average 88.85
# episode 336 score 109.84 100 game average 88.84
# episode 337 score 115.30 100 game average 89.91
# episode 338 score 93.57 100 game average 89.46
# episode 339 score 138.26 100 game average 89.62
# episode 340 score 149.17 100 game average 90.11
# episode 341 score 118.26 100 game average 90.93
# episode 342 score 127.62 100 game average 91.11
# episode 343 score 28.66 100 game average 90.50
# episode 344 score 54.80 100 game average 89.87
# episode 345 score 117.08 100 game average 90.51
# episode 346 score 90.51 100 game average 90.91
# episode 347 score 131.80 100 game average 90.71
# episode 348 score 149.65 100 game average 91.01
# episode 349 score 37.40 100 game average 90.58
# episode 350 score 87.76 100 game average 90.08
# episode 351 score -78.92 100 game average 88.21
# episode 352 score 116.89 100 game average 88.71
# episode 353 score 155.53 100 game average 89.29
# episode 354 score 71.42 100 game average 88.92
# episode 355 score 99.65 100 game average 89.36
# episode 356 score 152.04 100 game average 89.84
# episode 357 score 171.93 100 game average 91.44
# episode 358 score 155.43 100 game average 92.53
# episode 359 score 70.19 100 game average 92.30
# episode 360 score 40.19 100 game average 91.44
# episode 361 score 138.75 100 game average 91.66
# episode 362 score 78.02 100 game average 91.29
# episode 363 score -19.16 100 game average 90.82
# episode 364 score 141.49 100 game average 90.88
# episode 365 score 131.96 100 game average 91.32
# episode 366 score 177.17 100 game average 92.59
# episode 367 score 83.83 100 game average 92.99
# episode 368 score 113.17 100 game average 92.98
# episode 369 score 38.25 100 game average 93.62
# episode 370 score 152.51 100 game average 94.28
# episode 371 score 113.33 100 game average 94.24
# episode 372 score 95.44 100 game average 94.96
# episode 373 score 126.26 100 game average 95.38
# episode 374 score 125.67 100 game average 95.25
# episode 375 score 61.21 100 game average 95.63
# episode 376 score 147.87 100 game average 96.18
# episode 377 score 82.52 100 game average 95.87
# episode 378 score 137.77 100 game average 97.01
# episode 379 score 155.66 100 game average 97.01
# episode 380 score 23.39 100 game average 96.05
# episode 381 score 111.18 100 game average 96.08
# episode 382 score 74.39 100 game average 96.25
# episode 383 score 119.97 100 game average 96.31
# episode 384 score 110.10 100 game average 96.26
# episode 385 score 50.71 100 game average 96.09
# episode 386 score 71.29 100 game average 95.78
# episode 387 score 116.53 100 game average 95.69
# episode 388 score 116.75 100 game average 96.43
# episode 389 score 131.24 100 game average 96.37
# episode 390 score 47.50 100 game average 95.69
# episode 391 score 149.04 100 game average 96.53
# episode 392 score 115.48 100 game average 96.45
# episode 393 score 149.88 100 game average 96.84
# episode 394 score 119.90 100 game average 97.08
# episode 395 score 9.30 100 game average 95.98
# episode 396 score 152.48 100 game average 96.98
# episode 397 score 82.06 100 game average 96.58
# episode 398 score 106.23 100 game average 96.75
# episode 399 score 102.09 100 game average 96.70
# episode 400 score 53.41 100 game average 95.86
# episode 401 score 86.59 100 game average 96.28
# episode 402 score 110.42 100 game average 96.82
# episode 403 score 145.04 100 game average 97.53
# episode 404 score 81.72 100 game average 97.44
# episode 405 score 92.63 100 game average 97.01
# episode 406 score 99.51 100 game average 97.17
# episode 407 score 129.58 100 game average 98.13
# episode 408 score 41.91 100 game average 98.75
# episode 409 score 121.48 100 game average 99.22
# episode 410 score 70.89 100 game average 98.72
# episode 411 score 23.68 100 game average 97.60
# episode 412 score 87.13 100 game average 98.15
# episode 413 score 9.37 100 game average 97.33
# episode 414 score 133.11 100 game average 97.70
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[138], line 30
#      27 new_state, reward, done, info, _ = env.step(act)
#      29 agent.replay_buffer.append(obs, act, act_noise, reward, int(done), new_state)
# ---> 30 agent.update_parameters()
#      32 score += reward
#      34 if done:
#
# Cell In[136], line 66, in SAC_Agent.update_parameters(self)
#      61 intrinsic_reward = torch.norm(action_batch - noise_action_batch, p=2, dim=1, keepdim=True)
#      64 with torch.no_grad():
# ---> 66     next_state_action, next_state_log_pi, _, _ = self.policy.sample(next_state_batch)
#      68     qf1_next_target, qf2_next_target = self.critic_target(next_state_batch, next_state_action)
#      69     min_qf_next_target = torch.min(qf1_next_target, qf2_next_target) - self.alpha * next_state_log_pi
#
# Cell In[135], line 96, in GaussianPolicy.sample(self, state)
#      93 log_prob -= torch.log(self.action_scale * (1 - y_t.pow(2)) + epsilon)
#      94 log_prob = log_prob.sum(1, keepdim=True)
# ---> 96 mean = torch.tanh(mean) * self.action_scale + self.action_bias
#      97 return action, log_prob, mean, std
#
# KeyboardInterrupt:

# %%
agent.log_alpha
# Out:
# tensor([-3.1385], device='cuda:0', requires_grad=True)

# %%
# Out:
# array([ 0.11204466,  0.0933779 , -0.04886389,  0.04750442, -0.00756786,
#        -0.00516094,  0.02052993,  0.00720218])
